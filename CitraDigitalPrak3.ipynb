# %% [markdown]
# <a href="https://colab.research.google.com/github/adisdumpcode/CitraDigital/blob/main/CitraDigitalPrak3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

plt.plot((0,1,2,3),(4,2,6,4))
plt.plot((1,2,3,4), (2,3,4,5))
plt.title('PCD praktik')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
